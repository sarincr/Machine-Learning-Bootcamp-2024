# %%
import matplotlib.pyplot as plt

# %%
sizes = [20, 30, 25, 15, 10]

# %%
labels = ['A', 'B', 'C', 'D', 'E']

# %%
plt.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x79dfc378b2e0>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, 'A'),
#   Text(-0.64656382751384, 0.8899186574910392, 'B'),
#   Text(-0.7778173864806728, -0.777817532129725, 'C'),
#   Text(0.49938965983060557, -0.98010712049973, 'D'),
#   Text(1.0461622140716127, -0.3399185517867209, 'E')])

# %%
plt.pie(sizes, labels=labels)
plt.title('Pie Chart')
plt.show()

# %%
import matplotlib.pyplot as plt


x = [1, 2, 3, 4, 5]
y = [3, 5, 7, 2, 1]

# Plot lines
plt.plot(x, y)

# Add title and labels
plt.title("Simple Line Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Show the plot
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [3, 5, 7, 2, 1]

# Plot lines
plt.plot(x, y, color='green')

# Add title and labels
plt.title("Simple Line Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Show the plot
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [3, 5, 7, 2, 1]

# Create lists with shifted values
y_shifted_1 = [i + 1 for i in y]  # Add 1 to each element in y
y_shifted_2 = [i + 2 for i in y]  # Add 2 to each element in y
y_shifted_3 = [i + 3 for i in y]  # Add 3 to each element in y
y_shifted_4 = [i + 4 for i in y]  # Add 4 to each element in y

# Plot lines with different colors
plt.plot(x, y, color='r')  # Red (original y)
plt.plot(x, y_shifted_1, color='g')  # Green (shifted up by 1)
plt.plot(x, y_shifted_2, color='b')  # Blue (shifted up by 2)
plt.plot(x, y_shifted_3, color='k')  # Black (shifted up by 3)
plt.plot(x, y_shifted_4, color='c')  # Cyan (shifted up by 4)

# Add title and labels
plt.title("Simple Line Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Show the plot
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [3, 5, 7, 2, 1]

# Plot lines
plt.plot(x, y, color='green', linestyle="--")

# Add title and labels
plt.title("Simple Line Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Show the plot
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [3, 5, 7, 2, 1]

# Plot lines
plt.plot(x, y, color='green', linestyle="-.")

# Add title and labels
plt.title("Simple Line Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Show the plot
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [3, 5, 7, 2, 1]

# Plot lines
plt.plot(x, y, 'o')

# Add title and labels
plt.title("Simple Scatter Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Show the plot
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [2, 4, 6, 8, 10]
y2 = [1, 3, 5, 7, 9]

plt.plot(x, y1 )
plt.plot(x, y2 )
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Multiple Lines Plot')
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [2, 4, 6, 8, 10]
y2 = [1, 3, 5, 7, 9]

plt.plot(x, y1, label='Line 1')
plt.plot(x, y2, label='Line 2')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Multiple Lines Plot')
plt.legend()
plt.show()

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values = [5, 10, 15, 20, 25]

plt.bar(categories, values)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Simple Bar Chart')
plt.show()

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values = [5, 10, 15, 20, 25]

plt.bar(categories, values)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Simple Bar Chart')
plt.show()

# %%
data = [1, 1, 2, 3, 3, 3, 4, 4, 5, 5, 5, 5]

plt.hist(data, bins=5)
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %% [markdown]
# Histogram: Used for continuous numerical data. This means there are infinitely many possible values within a range. For example, heights of people, weights of objects, or temperatures.
#
#
# Bar Chart: Used for categorical data. This means the data falls into distinct categories with no values in between. Examples include types of fruits, colors of cars, or job titles.

# %%
# Data for histogram
x = [1, 1, 2, 3, 3, 3, 4, 4, 5, 5, 5, 5]

# Data for bar chart
y = [2, 4, 6, 8, 10]
categories = ['A', 'B', 'C', 'D', 'E']

# Create the histogram
plt.hist(x, bins=5, alpha=0.5, label='Histogram', color= "r")

# Create the bar chart
plt.bar(categories, y, alpha=0.5, label='Bar Chart')


# Add labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram vs. Bar Chart')

# Show the plot
plt.show()

# %%
x = ['A', 'B', 'C', 'D']
y1 = [10, 15, 7, 10]
y2 = [5, 8, 10, 15]

plt.bar(x, y1, label='Group 1')
plt.bar(x, y2, bottom=y1, label='Group 2')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Stacked Bar Chart')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt


x = [1, 2, 3, 4, 5]
y1 = [2, 5, 7, 3, 1]
y2 = [1, 3, 2, 5, 6]

# Create the plot
plt.fill_between(x, y1, y2, color='skyblue', alpha=0.4)  # Fill between the two lines

# Customize the plot
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Filled Area Chart')
plt.grid(True)

# Add lines for reference
plt.plot(x, y1, label='Line 1', color='blue')
plt.plot(x, y2, label='Line 2', color='red')
plt.legend()

# Display the plot
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

plt.step(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Step Plot')
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [2, 4, 6, 8, 10]
y2 = [1, 3, 5, 7, 9]

plt.stackplot(x, y1, y2)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Stacked Area Plot')
plt.show()

# %%
temperatures = [25, 27, 28, 26, 23, 24, 22, 29, 30, 28, 21, 25]
humidities = [60, 65, 70, 68, 62, 63, 60, 72, 75, 70, 58, 64]

# Create the hexbin plot
plt.hexbin(temperatures, humidities, gridsize=25, cmap="YlGnBu")  # Adjust gridsize for desired bin count

# Customize the plot
plt.xlabel("Temperature (°C)")
plt.ylabel("Humidity (%)")
plt.colorbar(label="Number of measurements")
plt.title("Temperature vs. Humidity Distribution")
plt.grid(True)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define specific X and Y coordinates
x = np.linspace(0, 10, 100)
y = np.linspace(0, 5, 50)

# Create a mathematical function for conductivity
def conductivity(x, y):
  # Replace this with your actual conductivity equation
  # This example creates a bumpy surface with a peak in the center
  return (x**2 - 25) + (y**2 - 16)

# Generate conductivity data using the defined coordinates
X, Y = np.meshgrid(x, y)
Z = conductivity(X, Y)

# Create the contour plot
fig, ax = plt.subplots()
levels = np.linspace(Z.min(), Z.max(), 10)  # Adjust for desired number of levels
CS = ax.contour(X, Y, Z, levels=levels, cmap='plasma')  # Use a colormap for conductivity

# Add labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('Conductivity (Condur) Plot')

# Add colorbar
plt.colorbar(CS, label='Conductivity')

plt.show()

# %%
r = np.linspace(0, 10, 100)
theta = [ 0.        ,  0.63466518,  1.26933037,  1.90399555,  2.53866073,
        3.17332591,  3.8079911 ,  4.44265628,  5.07732146,  5.71198664,
        6.34665183,  6.98131701,  7.61598219,  8.25064737,  8.88531256,
        9.51997774, 10.15464292, 10.7893081 , 11.42397329, 12.05863847,
       12.69330365, 13.32796883, 13.96263402, 14.5972992 , 15.23196438,
       15.86662956, 16.50129475, 17.13595993, 17.77062511, 18.40529029,
       19.03995548, 19.67462066, 20.30928584, 20.94395102, 21.57861621,
       22.21328139, 22.84794657, 23.48261175, 24.11727694, 24.75194212,
       25.3866073 , 26.02127248, 26.65593767, 27.29060285, 27.92526803,
       28.55993321, 29.1945984 , 29.82926358, 30.46392876, 31.09859394,
       31.73325913, 32.36792431, 33.00258949, 33.63725467, 34.27191986,
       34.90658504, 35.54125022, 36.1759154 , 36.81058059, 37.44524577,
       38.07991095, 38.71457614, 39.34924132, 39.9839065 , 40.61857168,
       41.25323687, 41.88790205, 42.52256723, 43.15723241, 43.7918976 ,
       44.42656278, 45.06122796, 45.69589314, 46.33055833, 46.96522351,
       47.59988869, 48.23455387, 48.86921906, 49.50388424, 50.13854942,
       50.7732146 , 51.40787979, 52.04254497, 52.67721015, 53.31187533,
       53.94654052, 54.5812057 , 55.21587088, 55.85053606, 56.48520125,
       57.11986643, 57.75453161, 58.38919679, 59.02386198, 59.65852716,
       60.29319234, 60.92785752, 61.56252271, 62.19718789, 62.83185307]

plt.polar(theta, r)
plt.title('Polar Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set the number of data points
num_points = 100

# Generate random angles between 0 and 2*pi (full circle)
theta = np.random.rand(num_points) * 2 * np.pi

# Generate random radii between 0 and 1
radius = np.random.rand(num_points)

# Create the polar plot
fig, ax = plt.subplots(subplot_kw=dict(projection='polar'))
ax.scatter(theta, radius, s=50, c='blue', alpha=0.7, label='Random Points')

# Set labels and title
ax.set_xlabel('Theta (radians)')
ax.set_ylabel('Radius')
ax.set_title('Random Polar Plot')

# Add legend
ax.legend()

plt.show()

# %%
x = range(5)
y = [10, 8, 6, 4, 2]
errors = [0.5, 0.4, 0.3, 0.2, 0.1]

plt.errorbar(x, y, yerr=errors, fmt='o')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Error Bars Plot')
plt.show()

# %%
x = np.linspace(0, 5, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title('Text Annotation Example')
plt.text(2, 0, 'Example Text', style='italic')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the first plot
x1 = np.linspace(0.0, 5.0, 100)
y1 = np.sin(2*np.pi*x1)

# Data for the second plot
x2 = np.linspace(0.0, 2.0, 50)
y2 = x2**2

# Create the figure and subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 5))  # 1 row, 2 columns

# Plot data on the first subplot
ax1.plot(x1, y1, label='Sine Wave')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_title('Sine Function')
ax1.legend()

# Plot data on the second subplot
ax2.plot(x2, y2, label='Square Function')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('Square Function')
ax2.legend()

# Adjust layout
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)
sizes = 1000 * np.random.rand(50)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5)
plt.title('Scatter Plot with Colors and Sizes')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt

sizes = [20, 30, 25, 15, 10]
labels = ['Apple', 'Orange', 'Banana', 'Mango', 'Grapes']
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen']
explode = (0.1, 0, 0, 0, 0)  # explode 1st slice

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True)
plt.title('Pie Chart of Fruit Distribution')
plt.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [np.random.normal(0, std, 100) for std in range(1, 4)]

plt.violinplot(data, vert=False)
plt.title('Violin Plot')
plt.xlabel('Value')
plt.ylabel('Distribution')
plt.show()

# %%
Y, X = np.mgrid[-3:3:100j, -3:3:100j]
U = -1 - X**2 + Y
V = 1 + X - Y**2

plt.streamplot(X, Y, U, V, color='b', linewidth=1.5)
plt.title('Streamplot of Vector Field')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
import seaborn as sns
import pandas as pd

# Sample data creation
data = {
    'x': range(1, 21),
    'y': [i*2 for i in range(1, 21)]
}
df = pd.DataFrame(data)

# Scatter plot
sns.scatterplot(x='x', y='y', data=df)

plt.show()

# %%
# Sample data creation
data = {
    'x': range(1, 21),
    'y': [i**2 for i in range(1, 21)]
}
df = pd.DataFrame(data)

# Line plot
sns.lineplot(x='x', y='y', data=df)
plt.title('Line Plot')
plt.show()

# %%
# Sample data creation
data = {
    'x': ['A', 'B', 'C', 'D', 'E'],
    'y': [10, 20, 15, 25, 30]
}
df = pd.DataFrame(data)

# Bar plot
sns.barplot(x='x', y='y', data=df)
plt.title('Bar Plot')
plt.show()

# %%
# Sample data creation
import numpy as np
data = np.random.normal(size=100)

# Histogram
sns.histplot(data)
plt.title('Histogram')
plt.show()

# %%
# Sample data creation
data = sns.load_dataset('iris')

# Pair plot
sns.pairplot(data, hue='species')
plt.title('Pair Plot')
plt.show()
